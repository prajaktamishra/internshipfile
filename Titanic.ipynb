# %% [markdown]
# <a href="https://colab.research.google.com/github/prajaktamishra/internshipfile/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
titanic=pd.read_csv('train.csv')

# %%
titanic.shape
# Out:
# (891, 12)

# %%
ports=pd.get_dummies(titanic.Embarked,prefix="Em")

# %%
ports.head()
# Out:
#    Em_C  Em_Q  Em_S
# 0     0     0     1
# 1     1     0     0
# 2     0     0     1
# 3     0     0     1
# 4     0     0     1

# %%
titanic=titanic.join(ports)

# %%
titanic.drop(['Embarked'],axis=1, inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Em_C         891 non-null    uint8
#  12  Em_Q         891 non-null    uint8
#  13  Em_S         891 non-null    uint8
# dtypes: float64(2), int64(5), object(4), uint8(3)
# memory usage: 79.3+ KB

# %%
titanic.Sex=titanic.Sex.map({'male':0,'female':1})

# %%
y=titanic.Survived.copy()

# %%
x=titanic.drop(['Survived'],axis=1)

# %%
x.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#    Sex   Age  SibSp  Parch            Ticket     Fare Cabin  Em_C  Em_Q  Em_S
# 0    0  22.0      1      0         A/5 21171   7.2500   NaN     0     0     1
# 1    1  38.0      1      0          PC 17599  71.2833   C85     1     0     0
# 2    1  26.0      0      0  STON/O2. 3101282   7.9250   NaN     0     0     1
# 3    1  35.0      1      0            113803  53.1000  C123     0     0     1
# 4    0  35.0      0      0            373450   8.0500   NaN     0     0     1

# %%
x.drop(['Cabin','Ticket','Name','PassengerId'],axis=1, inplace=True)

# %%
x.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Em_C  Em_Q  Em_S
# 0       3    0  22.0      1      0   7.2500     0     0     1
# 1       1    1  38.0      1      0  71.2833     1     0     0
# 2       3    1  26.0      0      0   7.9250     0     0     1
# 3       1    1  35.0      1      0  53.1000     0     0     1
# 4       3    0  35.0      0      0   8.0500     0     0     1

# %%
x.isnull().values.any()
# Out:
# True

# %%
x[pd.isnull(x).any(axis=1)]
# Out:
#      Pclass  Sex  Age  SibSp  Parch     Fare  Em_C  Em_Q  Em_S
# 5         3    0  NaN      0      0   8.4583     0     1     0
# 17        2    0  NaN      0      0  13.0000     0     0     1
# 19        3    1  NaN      0      0   7.2250     1     0     0
# 26        3    0  NaN      0      0   7.2250     1     0     0
# 28        3    1  NaN      0      0   7.8792     0     1     0
# ..      ...  ...  ...    ...    ...      ...   ...   ...   ...
# 859       3    0  NaN      0      0   7.2292     1     0     0
# 863       3    1  NaN      8      2  69.5500     0     0     1
# 868       3    0  NaN      0      0   9.5000     0     0     1
# 878       3    0  NaN      0      0   7.8958     0     0     1
# 888       3    1  NaN      1      2  23.4500     0     0     1
#
# [177 rows x 9 columns]

# %%
x.Age.fillna(x.Age.mean(), inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    int64
#  2   Age     891 non-null    float64
#  3   SibSp   891 non-null    int64
#  4   Parch   891 non-null    int64
#  5   Fare    891 non-null    float64
#  6   Em_C    891 non-null    uint8
#  7   Em_Q    891 non-null    uint8
#  8   Em_S    891 non-null    uint8
# dtypes: float64(2), int64(4), uint8(3)
# memory usage: 44.5 KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_valid,y_train,y_valid=train_test_split(x,y, test_size=0.2, random_state=7)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.8103932584269663

# %%
model.score(x_valid,y_valid)
# Out:
# 0.7541899441340782
